# %% [markdown]
# <p style="font-size:40px">GOOGLE SEARCH ANALYSIS</p>

# %% [markdown]
# <p style="font-size:25px">Importing Libraries:</p>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <p style="font-size:25px">Loading the Dataset:</p>

# %%
hb = pd.read_csv('google_trends_data.csv')
hb
# Out:
#                 Keyword       Category  Search Volume  \
# 0         Crypto Trends        Finance          44728
# 1         Oscar Winners  Entertainment          27472
# 2     iPhone 16 Release     Technology          51508
# 3          Fitness Apps         Health         168805
# 4          Stock Market        Finance          70191
# ...                 ...            ...            ...
# 1195        Health Tips         Health         142198
# 1196      SpaceX Launch        Science          51486
# 1197   Earthquake Japan           News         157976
# 1198      SpaceX Launch        Science         182583
# 1199       Fitness Apps         Health         112322
#
#       Interest Over Time (Jan)  Interest Over Time (Feb)  \
# 0                           55                        58
# 1                           65                        90
# 2                           86                        55
# 3                           93                        44
# ...

# %% [markdown]
# <p style="font-size:25px">Data Analysis and Cleaning:</p>

# %%
hb.index
# Out:
# RangeIndex(start=0, stop=1200, step=1)

# %%
hb.head()
# Out:
#              Keyword       Category  Search Volume  Interest Over Time (Jan)  \
# 0      Crypto Trends        Finance          44728                        55
# 1      Oscar Winners  Entertainment          27472                        65
# 2  iPhone 16 Release     Technology          51508                        86
# 3       Fitness Apps         Health         168805                        93
# 4       Stock Market        Finance          70191                        15
#
#    Interest Over Time (Feb)  Interest Over Time (Mar) Peak Month  Year
# 0                        58                        80        Mar  2025
# 1                        90                        50        Feb  2025
# 2                        55                         4        Mar  2025
# 3                        44                         4        Feb  2025
# 4                        78                        68        Feb  2025

# %%
hb.tail()
# Out:
#                Keyword Category  Search Volume  Interest Over Time (Jan)  \
# 1195       Health Tips   Health         142198                        31
# 1196     SpaceX Launch  Science          51486                         9
# 1197  Earthquake Japan     News         157976                         8
# 1198     SpaceX Launch  Science         182583                        53
# 1199      Fitness Apps   Health         112322                        18
#
#       Interest Over Time (Feb)  Interest Over Time (Mar) Peak Month  Year
# 1195                        56                        87        Mar  2025
# 1196                        17                        59        Feb  2025
# 1197                        67                        83        Mar  2025
# 1198                        73                        98        Jan  2025
# 1199                        82                        37        Mar  2025

# %%
hb.columns
# Out:
# Index(['Keyword', 'Category', 'Search Volume', 'Interest Over Time (Jan)',
#        'Interest Over Time (Feb)', 'Interest Over Time (Mar)', 'Peak Month',
#        'Year'],
#       dtype='object')

# %%
hb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Keyword                   1200 non-null   object
#  1   Category                  1200 non-null   object
#  2   Search Volume             1200 non-null   int64
#  3   Interest Over Time (Jan)  1200 non-null   int64
#  4   Interest Over Time (Feb)  1200 non-null   int64
#  5   Interest Over Time (Mar)  1200 non-null   int64
#  6   Peak Month                1200 non-null   object
#  7   Year                      1200 non-null   int64
# dtypes: int64(5), object(3)
# memory usage: 75.1+ KB

# %%
hb.shape
# Out:
# (1200, 8)

# %%
hb.drop_duplicates(inplace=True)
uni_rows=hb.shape[0]
uni_rows
# Out:
# 1200

# %%
hb.reset_index()
# Out:
#       index            Keyword       Category  Search Volume  \
# 0         0      Crypto Trends        Finance          44728
# 1         1      Oscar Winners  Entertainment          27472
# 2         2  iPhone 16 Release     Technology          51508
# 3         3       Fitness Apps         Health         168805
# 4         4       Stock Market        Finance          70191
# ...     ...                ...            ...            ...
# 1195   1195        Health Tips         Health         142198
# 1196   1196      SpaceX Launch        Science          51486
# 1197   1197   Earthquake Japan           News         157976
# 1198   1198      SpaceX Launch        Science         182583
# 1199   1199       Fitness Apps         Health         112322
#
#       Interest Over Time (Jan)  Interest Over Time (Feb)  \
# 0                           55                        58
# 1                           65                        90
# 2                           86                        55
# ...

# %%
null_value = hb.isnull() == True
hb.fillna(np.nan, inplace = True)

hb
# Out:
#                 Keyword       Category  Search Volume  \
# 0         Crypto Trends        Finance          44728
# 1         Oscar Winners  Entertainment          27472
# 2     iPhone 16 Release     Technology          51508
# 3          Fitness Apps         Health         168805
# 4          Stock Market        Finance          70191
# ...                 ...            ...            ...
# 1195        Health Tips         Health         142198
# 1196      SpaceX Launch        Science          51486
# 1197   Earthquake Japan           News         157976
# 1198      SpaceX Launch        Science         182583
# 1199       Fitness Apps         Health         112322
#
#       Interest Over Time (Jan)  Interest Over Time (Feb)  \
# 0                           55                        58
# 1                           65                        90
# 2                           86                        55
# 3                           93                        44
# ...

# %%
rem_val = hb.isnull().sum().sort_values(ascending=False)
rem_val
# Out:
# Keyword                     0
# Category                    0
# Search Volume               0
# Interest Over Time (Jan)    0
# Interest Over Time (Feb)    0
# Interest Over Time (Mar)    0
# Peak Month                  0
# Year                        0
# dtype: int64

# %%
print(hb.apply(lambda col: col.unique()))
# Out:
# Keyword                     [Crypto Trends, Oscar Winners, iPhone 16 Relea...
# Category                    [Finance, Entertainment, Technology, Health, T...
# Search Volume               [44728, 27472, 51508, 168805, 70191, 153958, 1...
# Interest Over Time (Jan)    [55, 65, 86, 93, 15, 70, 64, 18, 1, 96, 41, 46...
# Interest Over Time (Feb)    [58, 90, 55, 44, 78, 89, 65, 93, 68, 51, 53, 3...
# Interest Over Time (Mar)    [80, 50, 4, 68, 81, 13, 60, 91, 16, 19, 18, 56...
# Peak Month                                                    [Mar, Feb, Jan]
# Year                                                                   [2025]
# dtype: object

# %%
rem_val[:4]
# Out:
# Keyword                     0
# Category                    0
# Search Volume               0
# Interest Over Time (Jan)    0
# dtype: int64

# %% [markdown]
# <p style="font-size:25px">Aggregations:</p>

# %%
hb.min()
# Out:
# Keyword                        AI Tools
# Category                    Automobiles
# Search Volume                     10182
# Interest Over Time (Jan)              0
# Interest Over Time (Feb)              0
# Interest Over Time (Mar)              0
# Peak Month                          Feb
# Year                               2025
# dtype: object

# %%
hb.max()
# Out:
# Keyword                     iPhone 16 Release
# Category                               Travel
# Search Volume                          200000
# Interest Over Time (Jan)                  100
# Interest Over Time (Feb)                  100
# Interest Over Time (Mar)                  100
# Peak Month                                Mar
# Year                                     2025
# dtype: object

# %%
print(hb.columns)
# Out:
# Index(['Keyword', 'Category', 'Search Volume', 'Interest Over Time (Jan)',
#        'Interest Over Time (Feb)', 'Interest Over Time (Mar)', 'Peak Month',
#        'Year'],
#       dtype='object')

# %% [markdown]
# <p style="font-size:25px">Data Visualization</p>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
try:
    df = pd.read_csv('google_trends_data.csv')
except FileNotFoundError:
    print("Error: google_trends_data.csv not found. Please upload the file.")
    exit()
if df.empty:
    print("Error: google_trends_data.csv is empty.")
    exit()
try:
    category_col = df.columns[0]
    value_col = df.columns[1]
    df = df.rename(columns={category_col: 'Category', value_col: 'Value'})
except IndexError:
    print("Error: google_trends_data.csv does not have enough columns for plotting.")
    exit()


# 1. Vertical Bar Chart
plt.figure(figsize=(10, 6))
sns.barplot(x='Category', y='Value', data=df)
plt.title('Vertical Bar Chart')
plt.xlabel('Category')
plt.ylabel('Value')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Horizontal Bar Chart
plt.figure(figsize=(10, 6))
sns.barplot(x='Value', y='Category', data=df)
plt.title('Horizontal Bar Chart')
plt.xlabel('Value')
plt.ylabel('Category')
plt.tight_layout()
plt.show()

if len(df.columns) < 3:
    print("Adding a 'Group' column for demonstration of Grouped/Stacked charts.")
    # Create a dummy 'Group' column
    import numpy as np
    df['Group'] = np.random.choice(['Group A', 'Group B'], size=len(df))

# Grouped Bar Chart
if 'Group' in df.columns:
    plt.figure(figsize=(12, 6))
    sns.barplot(x='Category', y='Value', hue='Group', data=df)
    plt.title('Grouped Bar Chart')
    plt.xlabel('Category')
    plt.ylabel('Value')
    plt.xticks(rotation=45, ha='right')
    plt.legend(title='Group')
    plt.tight_layout()
    plt.show()
else:
    print("Skipping Grouped Bar Chart: 'Group' column not found or created.")

# Bar Plot with Color by Category
plt.figure(figsize=(10, 6))
sns.barplot(x='Category', y='Value', hue='Category', data=df, palette='viridis', legend=False)
plt.title('Bar Plot with Color by Category')
plt.xlabel('Category')
plt.ylabel('Value')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Skipping Grouped Bar Chart: 'Group' column not found or created.
